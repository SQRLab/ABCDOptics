# %%
from opticalSystemClass import OpticalSystem
import matplotlib.pyplot as plt

# %%
"""
    This script is used to test the beamFunctions.py script. We are going to generate a beam with some parameters and then propagate it
    through an optical system and then plot it. Currently we must assume that the beam is collimated when it comes out of the laser (ie R = 0).
    I have some concerns about the final answer but the code behave phenomenologically correct (sometimes?) at the very least.
    Please feel free to fix anything in opticalSystemClass.py. This code was initially written for me to try and understand ABCD matrices.
"""

# Parameters of the beam
wavelength = 422e-9 #422 nm
waist = 1000e-6 #beam waist (um)
z = 0 #initial position of the beam
theta = 0 #initial angle of the beam (rad)

system = OpticalSystem(wavelength, waist, z, theta) #generates initial beam

print(system.q)

# Generate optics in the path of the beam
system.freeSpace(.15) #free space of 0.1 m
system.lens(0.2) #lens with focal length of 0.15 m
system.freeSpace(.2) #free space of 0.1 m


system.propagate_beam() #propagates the beam through the optical system

print(f"The intial waist of the beam is {waist*1e6} um, initial angle is {theta} rad and position is {z} m")
print(f"The final waist of the beam is {system.waist_out*1e6} um")

print(system.q_out)
# Out:
# 7.4445323544781825j
# The intial waist of the beam is 1000.0 um, initial angle is 0 rad and position is 0 m
# The final waist of the beam is 26.865354393910902 um
# (3.608573553671224e-05+0.005372828514763534j)

# %%
"""
    Needs to be updated. Ignore this for now.
"""
system.plotBeamProfile() #plots the beam profile
